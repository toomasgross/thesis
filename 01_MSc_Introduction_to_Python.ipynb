# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("C:/Users/Toomas/Desktop/Data for playing/2020_dataset.csv")

# %%
# check the first 5 rows

df.head()
# Out:
#    survey_year  respondent_id  gender  age  age_group  \
# 0         2020              1       1   19          1
# 1         2020              2       1   19          1
# 2         2020              3       1   19          1
# 3         2020              5       1   19          1
# 4         2020              6       1   19          1
#
#    ethnicity_estonian_nonestonian  marital_status  education  \
# 0                               1             2.0        4.0
# 1                               1             1.0        2.0
# 2                               1             1.0        2.0
# 3                               1             1.0        2.0
# 4                               1             2.0        4.0
#
#    income_per_household_member  household_economic_comfort  ...  \
# 0                          3.0                         2.0  ...
# 1                          2.0                         2.0  ...
# 2                          5.0                         2.0  ...
# ...

# %%
# check the last 5 rows

df.tail()
# Out:
#       survey_year  respondent_id  gender  age  age_group  \
# 2165         2020           2319       2   60          5
# 2166         2020           2320       2   60          5
# 2167         2020           2321       2   60          5
# 2168         2020           2322       2   60          5
# 2169         2020           6040       2   60          5
#
#       ethnicity_estonian_nonestonian  marital_status  education  \
# 2165                               2             2.0        4.0
# 2166                               1             3.0        7.0
# 2167                               1             2.0        5.0
# 2168                               1             3.0        8.0
# 2169                               2             2.0        5.0
#
#       income_per_household_member  household_economic_comfort  ...  \
# 2165                          2.0                         2.0  ...
# 2166                          7.0                         1.0  ...
# ...

# %%
# check the dimensions of the dataframe

df.shape
# Out:
# (2170, 41)

# %%
# check the datatypes of the variables

df.dtypes
# Out:
# survey_year                                                         int64
# respondent_id                                                       int64
# gender                                                              int64
# age                                                                 int64
# age_group                                                           int64
# ethnicity_estonian_nonestonian                                      int64
# marital_status                                                    float64
# education                                                         float64
# income_per_household_member                                       float64
# household_economic_comfort                                        float64
# employment_status                                                 float64
# occupation_revised                                                float64
# health_assessment                                                 float64
# ...

# %%
# check the range of the rown indeces
df.index
# Out:
# RangeIndex(start=0, stop=2170, step=1)

# %%
# check the names of the columns
df.columns
# Out:
# Index(['survey_year', 'respondent_id', 'gender', 'age', 'age_group',
#        'ethnicity_estonian_nonestonian', 'marital_status', 'education',
#        'income_per_household_member', 'household_economic_comfort',
#        'employment_status', 'occupation_revised', 'health_assessment',
#        'chronic_disease', 'health_problem_limited_daily_activies',
#        'health_problem_limited_mobility', 'overtiredness', 'smoking_history',
#        'smoking_three_groups', 'smoking_two_groups',
#        'alcohol_general_consumption_frequency',
#        'alcohol_standard_units_consumption_frequency',
#        'special_diet_for_weightloss', 'special_diet_for_sports',
#        'habit_change_diet_for_weightloss',
#        'habit_change_more_physically_active', 'bmi', 'bmi_four_groups',
#        'bmi_three_groups', 'bmi_two_groups_split25', 'bmi_two_groups_split30',
#        'walk_cycle_daily_amount_for work',
#        'walk_cycle_daily_amount_for_leisure_working_days',
# ...

# %%
# show count, mean, std, min, etc for each variable
# some stat nonsensical for variables that are ordinal or nominal
df.describe()
# Out:
#        survey_year  respondent_id       gender          age    age_group  \
# count       2170.0    2170.000000  2170.000000  2170.000000  2170.000000
# mean        2020.0    1173.372350     1.597235    42.245161     3.258065
# std            0.0     681.019542     0.490567    13.572672     1.344950
# min         2020.0       1.000000     1.000000    16.000000     1.000000
# 25%         2020.0     582.250000     1.000000    31.000000     2.000000
# 50%         2020.0    1177.500000     2.000000    43.000000     3.000000
# 75%         2020.0    1757.750000     2.000000    54.000000     4.000000
# max         2020.0    6040.000000     2.000000    64.000000     5.000000
#
#        ethnicity_estonian_nonestonian  marital_status    education  \
# count                     2170.000000     2159.000000  2162.000000
# mean                         1.266359        1.925892     5.239593
# std                          0.442156        0.644411     1.852233
# ...

# %%
# makes more sense to calculate this for age and BMI only
df.loc[:,['age', 'bmi']].describe()
# Out:
#                age          bmi
# count  2170.000000  2170.000000
# mean     42.245161    26.125853
# std      13.572672     5.601251
# min      16.000000    13.600000
# 25%      31.000000    22.200000
# 50%      43.000000    25.100000
# 75%      54.000000    28.900000
# max      64.000000    70.600000

# %%
#subset of the dataframe (only bmi variable)
df['bmi']
# Out:
# 0       23.7
# 1       23.4
# 2       20.8
# 3       22.1
# 4       22.2
#         ...
# 2165    22.3
# 2166    34.5
# 2167    24.4
# 2168    24.9
# 2169    35.2
# Name: bmi, Length: 2170, dtype: float64

# %%
# show first two rows of hte dataframe
df[0:2]
# Out:
#    survey_year  respondent_id  gender  age  age_group  \
# 0         2020              1       1   19          1
# 1         2020              2       1   19          1
#
#    ethnicity_estonian_nonestonian  marital_status  education  \
# 0                               1             2.0        4.0
# 1                               1             1.0        2.0
#
#    income_per_household_member  household_economic_comfort  ...  \
# 0                          3.0                         2.0  ...
# 1                          2.0                         2.0  ...
#
#    walk_cycle_daily_amount_for work  \
# 0                               3.0
# 1                               4.0
#
#    walk_cycle_daily_amount_for_leisure_working_days  \
# 0                                               4.0
# 1                                               4.0
#
#    walk_cycle_daily_amount_non_working_days  exercising_frequency  \
# 0                                       4.0                   3.0
# ...

# %%
# show the values for each variable by a row index
df.iloc[1]
# Out:
# survey_year                                                       2020.0
# respondent_id                                                        2.0
# gender                                                               1.0
# age                                                                 19.0
# age_group                                                            1.0
# ethnicity_estonian_nonestonian                                       1.0
# marital_status                                                       1.0
# education                                                            2.0
# income_per_household_member                                          2.0
# household_economic_comfort                                           2.0
# employment_status                                                    1.0
# occupation_revised                                                   9.0
# health_assessment                                                    2.0
# ...

# %%
# show the first two rows of the data by index range
df.iloc[0:2]
# Out:
#    survey_year  respondent_id  gender  age  age_group  \
# 0         2020              1       1   19          1
# 1         2020              2       1   19          1
#
#    ethnicity_estonian_nonestonian  marital_status  education  \
# 0                               1             2.0        4.0
# 1                               1             1.0        2.0
#
#    income_per_household_member  household_economic_comfort  ...  \
# 0                          3.0                         2.0  ...
# 1                          2.0                         2.0  ...
#
#    walk_cycle_daily_amount_for work  \
# 0                               3.0
# 1                               4.0
#
#    walk_cycle_daily_amount_for_leisure_working_days  \
# 0                                               4.0
# 1                                               4.0
#
#    walk_cycle_daily_amount_non_working_days  exercising_frequency  \
# 0                                       4.0                   3.0
# ...

# %%
# show selected rows (indeces start from 0) and columns (numbers start from 1, the first being for the index)
# this show first two rows for columns 2 and 3
df.iloc[0:2,[2,3]]
# Out:
#    gender  age
# 0       1   19
# 1       1   19

# %%
# shows the dataframe (first 5 and last 5 rows) as True or False for missing values 
df.isna()
# Out:
#       survey_year  respondent_id  gender    age  age_group  \
# 0           False          False   False  False      False
# 1           False          False   False  False      False
# 2           False          False   False  False      False
# 3           False          False   False  False      False
# 4           False          False   False  False      False
# ...           ...            ...     ...    ...        ...
# 2165        False          False   False  False      False
# 2166        False          False   False  False      False
# 2167        False          False   False  False      False
# 2168        False          False   False  False      False
# 2169        False          False   False  False      False
#
#       ethnicity_estonian_nonestonian  marital_status  education  \
# 0                              False           False      False
# 1                              False           False      False
# ...
